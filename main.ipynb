# %% [markdown]
# # Single

# %%
from event_extractor.main import EventExtractor
from event_extractor.event import Event

doc_id_dict = {211: 'Charles Beaumont.txt'}

EventExtractor.extract(doc_id_dict)
# Out:
# main.py(64): id_ 211
# main.py(65): docID_list [211]
# main.py(39): [211]
# main.py(42): docID: 211
# stdout:  Number of test documents: 1 sentences: 67
#
# /workspace/EEtask/English_module_input_folder/outputs/output/211.event.entity
# []

# %% [markdown]
# # In a folder (Java command)

# %%
import os, shlex, subprocess

FILE_DIR_PATH = os.path.join(os.getcwd(), "event_extractor")
path2corenlp = os.path.join(FILE_DIR_PATH, "stanford-corenlp-full-2018-10-05")

# %%
def stanfordcorenlp_command(path2corenlp, inputfile):
    return "java -cp " + os.path.join(path2corenlp, "*") + " -Xmx8g edu.stanford.nlp.pipeline.StanfordCoreNLP " + " -annotators tokenize,ssplit,pos,depparse,lemma,ner,parse " + " -ner.applyFineGrained false " + " -file " + inputfile + " -outputFormat json "

CORENLP_INPUT_FOLDER = 'temp'
cmd = stanfordcorenlp_command(path2corenlp, os.path.join(CORENLP_INPUT_FOLDER, str(1)))  # store file as <docID>.json
args = shlex.split(cmd)
ret = subprocess.check_output(args)  # ignore return

# %%
from event_extractor.utils import lprint

# %% [markdown]
# # In a folder

# %%
from event_extractor.main import EventExtractor
from event_extractor.event import Event

doc_id_dict = {0: 'Zeroth Doc'}

EventExtractor.extract(doc_id_dict)
# Out:
# main.py(64): id_ 0
# main.py(65): docID_list [0]
# main.py(39): [0]
# main.py(42): docID: 0
# event.py(85): docID: '0' doc_id_dict: {0: 'Zeroth Doc'}
# stdout:  Number of test documents: 1 sentences: 3
#
# /workspace/EEtask/English_module_input_folder/outputs/output/0.event.entity

# %% [markdown]
# # Batch

# %%
import os
import json
from distutils.dir_util import copy_tree

def gen_doc_index(infolder, out_fname=None, write_to_text=False, write_to_json=False):

    from collections import OrderedDict
    import json
    import csv
    
    doc_id_dict = OrderedDict()
    
    files = (file for file in sorted(os.listdir(infolder)) 
         if os.path.isfile(os.path.join(infolder, file)))  # get only files
    
    for did, fname in enumerate(files): # ....txt
        doc_id_dict[did] = fname

    if write_to_json:
        with open(out_fname + '.json', 'w') as f:
            json.dump(doc_id_dict, f)
            
    if write_to_text:
        with open(out_fname + '.txt', 'w') as f:
            writer = csv.writer(f, delimiter='\t')
            writer.writerows(doc_id_dict.items())
            
    return doc_id_dict

def copy_and_rename(infolder, outfolder):
    
    import shutil

    if os.path.exists(outfolder):
        shutil.rmtree(outfolder)
    os.mkdir(outfolder)
    for did, fname in doc_id_dict.items():
        shutil.copy(os.path.join(infolder, fname), os.path.join('temp', str(did)))

# %%
from event_extractor.main import EventExtractor
from event_extractor.event import Event
from event_extractor.utils import lprint
import logging

# generate did list and copy the original files to a folder
input_folder = 'english_1990'
clean_fname_folder = 'temp'
doc_id_dict = gen_doc_index(infolder=input_folder, out_fname='did', write_to_text=True, write_to_json=True)
copy_and_rename(infolder=input_folder, outfolder=clean_fname_folder)

# batch 
for id_ in doc_id_dict.keys():
    logging.getLogger('info').info('--- start extracting doc ' + str(id_) + '---')
    EventExtractor.extract({id_: doc_id_dict[id_]})
    logging.getLogger('info').info('--- finish extracting ---')
# Out:
# main.py(64): id_ 0
# main.py(65): docID_list [0]
# main.py(39): [0]
# main.py(42): docID: 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4d04e569516a> in <module>
#      13 for id_ in doc_id_dict.keys():
#      14     logging.getLogger('info').info('--- start extracting doc ' + str(id_) + '---')
# ---> 15     EventExtractor.extract({id_: doc_id_dict[id_]})
#      16     logging.getLogger('info').info('--- finish extracting ---')
#
# /workspace/EEtask/English_module_input_folder/event_extractor/utils.py in timed(*args, **kw)
#      21             ts = time.time()
#      22             logging.getLogger(logger_name).info("Running function {}".format(method.__name__))
# ---> 23             result = method(*args, **kw)
#      24             te = time.time()
#      25             logging.getLogger(logger_name).info("function {} ran in {}s".format(method.__name__, round(te - ts, 2)))
#
# /workspace/EEtask/English_module_input_folder/event_extractor/main.py in extract(doc_id_dict)
#      70
#      71         # store CoreNLP json data
# ---> 72         data_dict = corenlp_gen_data(docID_list)
#      73         _, attr_dict = EventExtractor.get_text_attr(data_dict)
#      74         assert len(docID_list) == len(data_dict) == len(attr_dict)
#
# /workspace/EEtask/English_module_input_folder/event_extractor/utils.py in timed(*args, **kw)
#      21             ts = time.time()
#      22             logging.getLogger(logger_name).info("Running function {}".format(method.__name__))
# ---> 23             result = method(*args, **kw)
#      24             te = time.time()
#      25             logging.getLogger(logger_name).info("function {} ran in {}s".format(method.__name__, round(te - ts, 2)))
#
# /workspace/EEtask/English_module_input_folder/event_extractor/main.py in corenlp_gen_data(docID_list)
#      43         cmd = stanfordcorenlp_command(path2corenlp, os.path.join(CORENLP_INPUT_FOLDER, str(docID)))  # store file as <docID>.json
#      44         args = shlex.split(cmd)
# ---> 45         ret = subprocess.check_output(args)  # ignore return
#      46         info_logger.info(ret)
#      47         with open(str(docID) + ".json", 'r') as f:
#
# /usr/lib/python3.5/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     624
#     625     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 626                **kwargs).stdout
#     627
#     628
#
# /usr/lib/python3.5/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     693     with Popen(*popenargs, **kwargs) as process:
#     694         try:
# --> 695             stdout, stderr = process.communicate(input, timeout=timeout)
#     696         except TimeoutExpired:
#     697             process.kill()
#
# /usr/lib/python3.5/subprocess.py in communicate(self, input, timeout)
#    1057                 self._stdin_write(input)
#    1058             elif self.stdout:
# -> 1059                 stdout = self.stdout.read()
#    1060                 self.stdout.close()
#    1061             elif self.stderr:
#
# KeyboardInterrupt:

# %% [markdown]
# # Starting from 211 (Recovering from the interrupt)

# %%
from event_extractor.main import EventExtractor
from event_extractor.event import Event
from event_extractor.utils import lprint
import logging
import csv
import subprocess

info_logger = logging.getLogger('info')
error_logger = logging.getLogger('error')

with open('did.txt', 'r') as f:
    data = csv.reader(f, delimiter='\t')
    rest_data = list(data)[211:]

for item in rest_data:
    info_logger.info('--- start extracting doc ' + str(id_) + '---')
    try:
        EventExtractor.extract({item[0]: item[1]})
    except subprocess.CalledProcessError as e:
        error_logger.error('[docID] {} [doc] {} \n[stderr/stdout]: \n{}'.format(
            item[0], item[1], str(e.output)))
    info_logger.info('--- finish extracting ---')
# Out:
# {'211': 'Charles Beaumont.txt'}
# {'212': 'Charles Burnett (director).txt'}
# {'213': 'Charles Correll.txt'}
# {'214': 'Charles Durning.txt'}
# {'215': 'Charles Grodin.txt'}
# {'216': 'Charles Haid.txt'}
# {'217': 'Charles Robert Carner.txt'}
# {'218': 'Charles S. Haas.txt'}
# {'219': 'Charlie Korsmo.txt'}
# {'220': 'Charlie Sheen.txt'}
# {'221': 'Charlton Heston.txt'}
# {'222': 'Cheech Marin.txt'}
# {'223': 'Cher.txt'}
# {'224': 'Cheryl Ladd.txt'}
# {'225': 'Cheryl Pollak.txt'}
# {'226': "Child's Play 2.txt"}
# {'227': 'Childhood Days.txt'}
# {'228': 'China Cry.txt'}
# {'229': 'Chishū Ryū.txt'}
# {'230': 'Chloe Webb.txt'}
# {'231': 'Chris Columbus (filmmaker).txt'}
# {'232': 'Chris Eigeman.txt'}
# {'233': 'Chris Furrh.txt'}
# {'234': "Chris O'Donnell.txt"}
# {'235': 'Chris Phillips.txt'}
# {'236': 'Chris Rock.txt'}
# {'237': 'Christian Bale.txt'}
# {'238': 'Christian Clemenson.txt'}
# {'239': 'Christian Serratos.txt'}
# {'240': 'Christian Slater.txt'}
# {'241': 'Christina Ricci.txt'}
# {'242': 'Christine Ebersole.txt'}
# {'243': 'Christine Elise.txt'}
# {'244': 'Christine Lahti.txt'}
# {'245': 'Christopher -Kid- Reid.txt'}
# {'246': 'Christopher Atkins.txt'}
# {'247': 'Christopher Cazenove.txt'}
# {'248': 'Christopher Lee.txt'}
# {'249': 'Christopher Lloyd.txt'}
# {'250': 'Christopher Martin (entertainer).txt'}
# {'251': 'Christopher Massey.txt'}
# {'252': 'Christopher Plummer.txt'}
# {'253': 'Christopher Walken.txt'}
# {'254': 'Chuck Norris.txt'}
# {'255': 'Chuck Pfarrer.txt'}
# {'256': 'Chuck Williams (actor) (page does not exist).txt'}
# {'257': 'Cinema Paradiso.txt'}
# {'258': 'City Hunter- Bay City Wars.txt'}
# {'259': 'Class of 1999.txt'}
# {'260': 'Claudio Fragasso.txt'}
# {'261': 'Clayton Landey.txt'}
# {'262': 'Cleavant Derricks (actor).txt'}
# {'263': 'Clint Eastwood.txt'}
# {'264': 'Clive Barker.txt'}
# {'265': 'Cloris Leachman.txt'}
# {'266': 'Close-Up (1990 film).txt'}
# {'267': 'Coen brothers.txt'}
# {'268': 'Coins in the Fountain.txt'}
# {'269': 'Colin Friels.txt'}
# {'270': 'Columbia Pictures.txt'}
# {'271': 'Come See the Paradise.txt'}
# {'272': 'Comedy film.txt'}
# {'273': 'Computer graphics.txt'}
# {'274': 'Computer-generated imagery.txt'}
# {'275': 'Connie Young.txt'}
# {'276': 'Conrad Dunn.txt'}
# {'277': 'Corey Feldman.txt'}
# {'278': 'Corey Parker (actor).txt'}
# {'279': 'Coupe de Ville (film).txt'}
# {'280': 'Courage Mountain.txt'}
# {'281': 'Courtney Gains.txt'}
# {'282': 'Courtney Thorne-Smith.txt'}
# {'283': 'Craig R. Baxley.txt'}
# {'284': 'Craig Sheffer.txt'}
# {'285': 'Crash and Burn (1990 film).txt'}
# {'286': 'Crazy People.txt'}
# {'287': 'Crime fiction.txt'}
# {'288': 'Crispin Glover.txt'}
# {'289': 'Cry-Baby.txt'}
# {'290': 'Curtis Hanson.txt'}
# {'291': 'Cybill Shepherd.txt'}
# {'292': 'Cynda Williams.txt'}
# {'293': 'Cynthia Brimhall.txt'}
# {'294': 'Cynthia Gibb.txt'}
# {'295': 'Cyrano de Bergerac (1990 film).txt'}
# {'296': "Cyril O'Reilly.txt"}
# {'297': 'D. B. Sweeney.txt'}
# {'298': 'Dabney Coleman.txt'}
# {'299': 'Damon Wayans.txt'}
# {'300': 'Dan Aykroyd.txt'}
# {'301': 'Dan Greenburg.txt'}
# {'302': "Dan O'Bannon.txt"}
# {'303': "Dan O'Herlihy.txt"}
# {'304': 'Dana Carvey.txt'}
# {'305': 'Dances with Wolves.txt'}
# {'306': 'Daniel Stern (actor).txt'}
# {'307': 'Daniel Waters (screenwriter).txt'}
# {'308': 'Danny Aiello.txt'}
# {'309': 'Danny Glover.txt'}
# {'310': 'Danny Trejo.txt'}
# {'311': 'Danton Stone.txt'}
# {'312': 'Danuel Pipoly.txt'}
# {'313': 'Darkman.txt'}
# {'314': 'Darren E. Burrows.txt'}
# {'315': 'Daryl Hannah.txt'}
# {'316': 'Daveigh Chase.txt'}
# {'317': 'David -Shark- Fralick.txt'}
# {'318': 'David Ackroyd.txt'}
# {'319': 'David Andrews (actor).txt'}
# {'320': 'David Argue.txt'}
# {'321': 'David Arnott.txt'}
# {'322': 'David Carradine.txt'}
# {'323': 'David Caruso.txt'}
# {'324': 'David Cronenberg.txt'}
# {'325': 'David Frankel.txt'}
# {'326': 'David Green (director).txt'}
# {'327': 'David Hand (animator).txt'}
# {'328': 'David Hewlett.txt'}
# {'329': 'David J. Schow.txt'}
# {'330': 'David Johansen.txt'}
# {'331': 'David Koepp.txt'}
# {'332': 'David Loughery.txt'}
# {'333': 'David Lynch.txt'}
# {'334': 'David Marshall Grant.txt'}
# {'335': 'David Morse (actor).txt'}
# {'336': 'David N. Weiss.txt'}
# {'337': 'David Patrick Kelly.txt'}
# {'338': 'David Rayfiel.txt'}
# {'339': 'David S. Goyer.txt'}
# {'340': 'David Seltzer.txt'}
# {'341': 'David Strathairn.txt'}
# {'342': 'Days of Being Wild.txt'}
# {'343': 'Days of Thunder.txt'}
# {'344': 'Dean Cameron.txt'}
# {'345': 'Death Warrant (film).txt'}
# {'346': 'Debbie Harry.txt'}
# {'347': 'Deborah Kara Unger.txt'}
# {'348': 'Debra Winger.txt'}
# {'349': 'Deems Taylor.txt'}
# {'350': 'Dei tau lung (page does not exist).txt'}
# {'351': 'Delta Force 2- The Colombian Connection.txt'}
# {'352': 'Demi Moore.txt'}
# {'353': 'Denial (1990 film).txt'}
# {'354': 'Denis Whitburn.txt'}
# {'355': 'Denise Nicholas.txt'}
# {'356': 'Dennis Burkley.txt'}
# {'357': 'Dennis Dugan.txt'}
# {'358': 'Dennis Haysbert.txt'}
# {'359': 'Dennis Hopper.txt'}
# {'360': 'Dennis Lipscomb.txt'}
# {'361': 'Dennis Marks (screenwriter).txt'}
# {'362': 'Dennis Miller.txt'}
# {'363': 'Dennis Quaid.txt'}
# {'364': 'Denzel Washington.txt'}
# {'365': 'Deran Sarafian.txt'}
# {'366': 'Desperate Hours.txt'}
# {'367': 'Dev Patel.txt'}
# {'368': 'Devin DeVasquez.txt'}
# {'369': 'Diane Keaton.txt'}
# {'370': 'Diane Ladd.txt'}
# {'371': 'Dianne Wiest.txt'}
# {'372': 'Dick Anthony Williams.txt'}
# {'373': 'Dick Huemer.txt'}
# {'374': 'Dick Tracy (1990 film).txt'}
# {'375': 'Dick Van Dyke.txt'}
# {'376': 'Die Hard 2.txt'}
# {'377': 'Digital puppetry.txt'}
# {'378': 'Dinah Manoff.txt'}
# {'379': 'Djimon Hounsou.txt'}
# {'380': 'Dolph Lundgren.txt'}
# {'381': 'Dom DeLuise.txt'}
# {'382': 'Don Collier.txt'}
# {'383': 'Don Johnson.txt'}
# {'384': 'Don Mancini.txt'}
# {'385': 'Don Messick.txt'}
# {'386': "Don't Tell Her It's Me.txt"}
# {'387': 'Dona Speir.txt'}
# {'388': 'Donald E. Stewart.txt'}
# {'389': 'Donald Petrie.txt'}
# {'390': 'Donatello (Teenage Mutant Ninja Turtles).txt'}
# {'391': 'Dorian Harewood.txt'}
# {'392': 'Doris Hare.txt'}
# {'393': 'Doug Richardson.txt'}
# {'394': 'Douglas Barr.txt'}
# {'395': 'Douglas Seale.txt'}
# {'396': 'Downtown (film).txt'}
# {'397': 'Drama film.txt'}
# {'398': 'Dreams (1990 film).txt'}
# {'399': 'Driving Miss Daisy.txt'}
# {'400': 'DuckTales the Movie- Treasure of the Lost Lamp.txt'}
# {'401': 'Dudley Moore.txt'}
# {'402': 'Dustin Hoffman.txt'}
# {'403': 'Dwier Brown.txt'}
# {'404': 'Dwight H. Little.txt'}
# {'405': 'Dyan Cannon.txt'}
# {'406': 'Dylan McDermott.txt'}
# {'407': 'Ed Flanders.txt'}
# {'408': 'Ed Harris.txt'}
# {'409': "Ed O'Neill.txt"}
# {'410': "Ed O'Ross.txt"}
# {'411': 'Eddie Frierson.txt'}
# {'412': 'Eddie Murphy.txt'}
# {'413': 'Edmond Rostand.txt'}
# {'414': 'Edward Asner.txt'}
# {'415': 'Edward Scissorhands.txt'}
# {'416': 'Eileen Brennan.txt'}
# {'417': 'El Diablo (1990 film).txt'}
# {'418': 'Eli Wallach.txt'}
# {'419': 'Elias Koteas.txt'}
# {'420': 'Elizabeth Gracen.txt'}
# {'421': 'Elizabeth McGovern.txt'}
# {'422': 'Elizabeth Peña.txt'}
# {'423': 'Elizabeth Perkins.txt'}
# {'424': 'Ellen Greene.txt'}
# {'425': 'Emile Ardolino.txt'}
# {'426': 'Emilio Estevez.txt'}
# {'427': 'Emma Watson.txt'}
# {'428': 'Empire International Pictures.txt'}
# {'429': 'Ennio Morricone.txt'}
# {'430': 'Eric Idle.txt'}
# {'431': 'Eric Roberts.txt'}
# {'432': 'Eric Stoltz.txt'}
# {'433': 'Erik Estrada.txt'}
# {'434': 'Ernest Goes to Jail.txt'}
# {'435': 'Europa Europa.txt'}
# {'436': 'Eva Gabor.txt'}
# {'437': 'Evan Jones (writer).txt'}
# {'438': 'Everybody Wins (film).txt'}
# {'439': 'F.X. Feeney.txt'}
# {'440': 'Family film.txt'}
# {'441': 'Fantasia (1940 film).txt'}
# {'442': 'Fantasy film.txt'}
# {'443': 'Far Out Man.txt'}
# {'444': 'Faye Dunaway.txt'}
# {'445': 'Felix the Cat- The Movie.txt'}
# {'446': 'Film Workshop.txt'}
# {'447': 'Film treatment.txt'}
# {'448': 'Finn Carter.txt'}
# {'449': 'Fiona Shaw.txt'}
# {'450': 'Fire Birds.txt'}
# {'451': 'Flashback (1990 film).txt'}
# {'452': 'Flatliners.txt'}
# {'453': 'Ford Beebe.txt'}
# {'454': 'Forest Whitaker.txt'}
# {'455': 'Fran Drescher.txt'}
# {'456': 'France Nuyen.txt'}
# {'457': 'Frances McDormand.txt'}
# {'458': 'Frances Sternhagen.txt'}
# {'459': 'Francis Ford Coppola.txt'}
# {'460': 'Franco Amurri.txt'}
# {'461': 'Franco Nero.txt'}
# {'462': 'Franco Zeffirelli.txt'}
# {'463': 'Frank Henenlotter.txt'}
# {'464': 'Frank Marshall (film producer).txt'}
# {'465': 'Frank Miller (comics).txt'}
# {'466': 'Frank Pierson.txt'}
# {'467': 'Frank Welker.txt'}
# {'468': 'Frank Whaley.txt'}
# {'469': 'Frankenhooker.txt'}
# {'470': 'Frankenstein Unbound.txt'}
# {'471': 'Fred Schepisi.txt'}
# {'472': 'Fred Ward.txt'}
# {'473': 'Frederick Coffin.txt'}
# {'474': 'Funny About Love.txt'}
# {'475': 'Gabriel Byrne.txt'}
# {'476': 'Gabriel Damon.txt'}
# {'477': 'Gailard Sartain.txt'}
# {'478': 'Garry Marshall.txt'}
# {'479': 'Gary Busey.txt'}
# {'480': 'Gary Goldman (screenwriter).txt'}
# {'481': 'Gary Graham.txt'}
# {'482': 'Gary Kemp.txt'}
# {'483': 'Gary Kroeger.txt'}
# {'484': 'Gary Oldman.txt'}
# {'485': 'Gary Sherman (director).txt'}
# {'486': 'Gates McFadden.txt'}
# {'487': 'Geena Davis.txt'}
# {'488': 'Gene Hackman.txt'}
# {'489': 'Gene Wilder.txt'}
# {'490': 'Geoff Murphy.txt'}
# {'491': 'Geoffrey Lewis (actor).txt'}
# {'492': 'George A. Romero.txt'}
# {'493': 'George Armitage.txt'}
# {'494': 'George C. Scott.txt'}
# {'495': 'George Clinton (musician).txt'}
# {'496': 'George Dickerson.txt'}
# {'497': 'George Dzundza.txt'}
# {'498': 'George Hamilton (actor).txt'}
# {'499': 'George Kennedy.txt'}
# {'500': 'George Lopez.txt'}
# {'501': "George O'Hanlon.txt"}
# {'502': 'George Takei.txt'}
# {'503': 'Gerrit Graham.txt'}
# {'504': 'Gérard Depardieu.txt'}
# {'505': 'Ghost (1990 film).txt'}
# {'506': 'Ghost Dad.txt'}
# {'507': 'Gia Mantegna.txt'}
# {'508': 'Giancarlo Esposito.txt'}
# {'509': 'Gilbert Gottfried.txt'}
# {'510': 'Giuseppe Tornatore.txt'}
# {'511': 'Glenn Close.txt'}
# {'512': 'Glenne Headly.txt'}
# {'513': 'Goldie Hawn.txt'}
# {'514': 'Gong Li.txt'}
# {'515': 'Goodfellas.txt'}
# {'516': 'Grace Zabriskie.txt'}
# {'517': 'Graffiti Bridge (film).txt'}
# {'518': 'Graham Greene (actor).txt'}
# {'519': 'Graveyard Shift (1990 film).txt'}
# {'520': 'Green Card (film).txt'}
# {'521': 'Greg Snegoff (page does not exist).txt'}
# {'522': 'Gregg Berger.txt'}
# {'523': 'Gremlins 2- The New Batch.txt'}
# {'524': 'Greta Scacchi.txt'}
# {'525': 'Greydon Clark.txt'}
# {'526': 'Guns (film).txt'}
# {'527': 'Guy Pearce.txt'}
# {'528': 'HBO Pictures.txt'}
# {'529': 'Hamilton Luske.txt'}
# {'530': 'Hamlet (1990 film).txt'}
# {'531': 'Hank Azaria.txt'}
# {'532': 'Hanna-Barbera.txt'}
# {'533': 'Happily Ever After (1990 film).txt'}
# {'534': 'Hard to Kill.txt'}
# {'535': 'Hardware (film).txt'}
# {'536': 'Harley Jane Kozak.txt'}
# {'537': 'Harold Pinter.txt'}
# {'538': 'Harriet Frank, Jr..txt'}
# {'539': 'Harrison Ford.txt'}
# {'540': 'Harry Connick, Jr..txt'}
# {'541': 'Harry Dean Stanton.txt'}
# {'542': 'Harry Eden.txt'}
# {'543': 'Harry Hook.txt'}
# {'544': 'Hart Bochner.txt'}
# {'545': 'Harvey Keitel.txt'}
# {'546': 'Havana (film).txt'}
# {'547': 'Heart Condition (film).txt'}
# {'548': 'Heaven Tonight (film).txt'}
# {'549': 'Heaven and Earth (1990 film).txt'}
# {'550': 'Hector Elizondo.txt'}
# {'551': 'Helen Mirren.txt'}
# {'552': 'Helena Bonham Carter.txt'}
# {'553': 'Henry & June.txt'}
# {'554': 'Henry Bean.txt'}
# {'555': 'Henry Winkler.txt'}
# {'556': 'Henry- Portrait of a Serial Killer.txt'}
# {'557': 'Herbert Ross.txt'}
# {'558': 'Héctor Elizondo.txt'}
# {'559': 'Hidden Agenda (1990 film).txt'}
# {'560': 'Hollywood Pictures.txt'}
# {'561': 'Home Alone.txt'}
# {'562': 'Hope Davis.txt'}
# {'563': 'Horror film.txt'}
# {'564': 'House Party (film).txt'}
# {'565': 'Howard Franklin.txt'}
# {'566': "Hugh O'Brian.txt"}
# {'567': 'Hugh Parks (page does not exist).txt'}
# {'568': 'I Come in Peace.txt'}
# {'569': 'I Love You to Death.txt'}
# {'570': 'Iain Glen.txt'}
# {'571': 'Ian Bannen.txt'}
# {'572': 'Iggy Pop.txt'}
# {'573': 'Imagine Entertainment.txt'}
# {'574': 'Indiana Evans.txt'}
# {'575': 'Ingrid Chavez.txt'}
# {'576': 'Internal Affairs (film).txt'}
# {'577': 'Interscope Communications.txt'}
# {'578': 'Irene Cara.txt'}
# {'579': 'Irvin Kershner.txt'}
# {'580': 'Irving Ravetch.txt'}
# {'581': 'Isabella Rossellini.txt'}
# {'582': 'Ishirō Honda.txt'}
# {'583': 'Ivan Raimi.txt'}
# {'584': 'Ivan Reitman.txt'}
# {'585': 'J. E. Freeman.txt'}
# {'586': 'J. Eddie Peck.txt'}
# {'587': 'J. F. Lawton.txt'}
# {'588': 'J. J. Abrams.txt'}
# {'589': 'J. J. Anderson.txt'}
# {'590': 'J. T. Walsh.txt'}
# {'591': 'Jack Bannon.txt'}
# {'592': 'Jack Epps, Jr..txt'}
# {'593': 'Jack Lowden.txt'}
# {'594': 'Jack Nicholson.txt'}
# {'595': "Jack O'Connell (actor).txt"}
# {'596': 'Jack Warden.txt'}
# {'597': 'Jacky Cheung.txt'}
# {'598': "Jacob's Ladder (1990 film).txt"}
# {'599': 'Jake Thomas.txt'}
# {'600': 'James Algar.txt'}
# {'601': 'James Arness.txt'}
# {'602': 'James Belushi.txt'}
# {'603': 'James Bridges.txt'}
# {'604': 'James Brolin.txt'}
# {'605': 'James Caan (actor).txt'}
# {'606': 'James Caan.txt'}
# {'607': 'James Coburn.txt'}
# {'608': 'James D. Parriott.txt'}
# {'609': 'James Earl Jones.txt'}
# {'610': 'James Foley (director).txt'}
# {'611': 'James Fox (actor).txt'}
# {'612': 'James Hampton (actor).txt'}
# {'613': 'James Horner.txt'}
# {'614': 'James Maslow.txt'}
# {'615': 'James Orr (filmmaker).txt'}
# {'616': 'James Remar.txt'}
# {'617': 'James Shigeta.txt'}
# {'618': 'James Spader.txt'}
# {'619': 'James Tolkan.txt'}
# {'620': 'Jami Gertz.txt'}
# {'621': 'Jamie Lee Curtis.txt'}
# {'622': 'Jane Fonda.txt'}
# {'623': 'Jane Horrocks.txt'}
# {'624': 'Janet Suzman.txt'}
# {'625': 'Jasen Fisher.txt'}
# {'626': 'Jason Alexander.txt'}
# {'627': 'Jason F. Wright.txt'}
# {'628': 'Jason Miller (playwright).txt'}
# {'629': 'Jason Patric.txt'}
# {'630': 'Jason Robards.txt'}
# {'631': 'Javier Bardem.txt'}
# {'632': 'Jay Bilas.txt'}
# {'633': 'Jay Presson Allen.txt'}
# {'634': 'Jay Sandrich.txt'}
# {'635': 'Jean Reiner (page does not exist).txt'}
# {'636': 'Jean Vander Pyl.txt'}
# {'637': 'Jean-Claude Carrière.txt'}
# {'638': 'Jean-Claude Van Damme.txt'}
# {'639': 'Jean-Luc Bilodeau.txt'}
# {'640': 'Jean-Paul Rappeneau.txt'}
# {'641': 'Jeb Stuart (writer).txt'}
# {'642': 'Jeff Bridges.txt'}
# {'643': 'Jeff Burr.txt'}
# {'644': 'Jeff Daniels.txt'}
# {'645': 'Jeff Fahey.txt'}
# {'646': 'Jeff James.txt'}
# {'647': 'Jeff Kober.txt'}
# {'648': 'Jennifer Connelly.txt'}
# {'649': 'Jennifer Jason Leigh.txt'}
# {'650': 'Jennifer Lawrence.txt'}
# {'651': 'Jenny Agutter.txt'}
# {'652': 'Jenny Seagrove.txt'}
# {'653': 'Jeremy Irons.txt'}
# {'654': 'Jeremy Suarez.txt'}
# {'655': 'Jerome Benton.txt'}
# {'656': 'Jerry Bruckheimer.txt'}
# {'657': 'Jerry Zucker (film director).txt'}
# {'658': 'Jessica Lundy.txt'}
# {'659': 'Jessica Tandy.txt'}
# {'660': 'Jetsons- The Movie.txt'}
# {'661': 'Jim Abrahams.txt'}
# {'662': 'Jim Beaver.txt'}
# {'663': 'Jim Broadbent.txt'}
# {'664': 'Jim Cash.txt'}
# {'665': 'Jim Thomas (screenwriter).txt'}
# {'666': 'Jim Varney.txt'}
# {'667': 'JoJo (singer).txt'}
# {'668': 'JoJo.txt'}
# {'669': 'Joan Cusack.txt'}
# {'670': 'Joan Plowright.txt'}
# {'671': 'Joan Severance.txt'}
# {'672': 'Joanna Cassidy.txt'}
# {'673': 'Joanna Pacuła.txt'}
# {'674': 'Joanne Whalley.txt'}
# {'675': 'Joanne Woodward.txt'}
# {'676': 'Jodie Foster.txt'}
# {'677': 'Joe Dante.txt'}
# {'678': 'Joe Estevez.txt'}
# {'679': 'Joe Grant.txt'}
# {'680': 'Joe Haldeman.txt'}
# {'681': 'Joe Lara.txt'}
# {'682': 'Joe Mantegna.txt'}
# {'683': 'Joe Pantoliano.txt'}
# {'684': 'Joe Pesci.txt'}
# {'685': 'Joe Ranft.txt'}
# {'686': 'Joe Roth.txt'}
# {'687': 'Joe Unger.txt'}
# {'688': 'Joe Versus the Volcano.txt'}
# {'689': 'Joel Schumacher.txt'}
# {'690': 'Joel and Ethan Coen.txt'}
# {'691': 'Joey Bishop.txt'}
# {'692': 'John & Brandy (page does not exist).txt'}
# {'693': 'John Amos.txt'}
# {'694': 'John Bach.txt'}
# {'695': 'John Badham.txt'}
# {'696': 'John Barry (composer).txt'}
# {'697': 'John Blumenthal.txt'}
# {'698': 'John Boorman.txt'}
# {'699': 'John C. Reilly.txt'}
# {'700': 'John Candy.txt'}
# {'701': 'John Carpenter.txt'}
# {'702': 'John Clark Gable.txt'}
# {'703': 'John Clarke (satirist).txt'}
# {'704': 'John Cornell.txt'}
# {'705': 'John Cusack.txt'}
# {'706': 'John Diehl (actor).txt'}
# {'707': 'John Erman.txt'}
# {'708': 'John Eskow.txt'}
# {'709': 'John Fusco.txt'}
# {'710': 'John G. Avildsen.txt'}
# {'711': 'John Getz.txt'}
# {'712': 'John Glover (actor).txt'}
# {'713': 'John Goodman.txt'}
# {'714': 'John Harrison (director).txt'}
# {'715': 'John Heard (actor).txt'}
# {'716': 'John Hill (screenwriter).txt'}
# {'717': 'John Hughes (filmmaker).txt'}
# {'718': 'John Hurt.txt'}
# {'719': 'John Kamps (page does not exist).txt'}
# {'720': 'John Kostmayer (page does not exist).txt'}
# {'721': 'John Lafia.txt'}
# {'722': 'John Larroquette.txt'}
# {'723': 'John Leguizamo.txt'}
# {'724': 'John Lithgow.txt'}
# {'725': 'John Lynch (actor).txt'}
# {'726': 'John Mackenzie (film director).txt'}
# {'727': 'John Mahoney.txt'}
# {'728': 'John Malkovich.txt'}
# {'729': 'John McTiernan.txt'}
# {'730': 'John P. Ryan (actor).txt'}
# {'731': 'John Patrick Shanley.txt'}
# {'732': 'John Platt (screenwriter) (page does not exist).txt'}
# {'733': 'John Polson.txt'}
# {'734': 'John R. Cherry III.txt'}
# {'735': 'John Ritter.txt'}
# {'736': 'John Schlesinger.txt'}
# {'737': 'John Thomas (screenwriter).txt'}
# {'738': 'John Travolta.txt'}
# {'739': 'John Turturro.txt'}
# {'740': 'John Waters (filmmaker).txt'}
# {'741': 'John Waters.txt'}
# {'742': 'John de Lancie.txt'}
# {'743': 'Johnny Depp.txt'}
# {'744': 'Joie Lee.txt'}
# {'745': 'Jon Lovitz.txt'}
# {'746': 'Jon Polito.txt'}
# {'747': 'Jonathan Lipnicki.txt'}
# {'748': 'Jonathan Lynn.txt'}
# {'749': 'Jonathan Penner.txt'}
# {'750': 'Joseph Barbera.txt'}
# {'751': 'Joseph Mazzello.txt'}
# {'752': "Josh O'Connor.txt"}
# {'753': 'Josh Pais.txt'}
# {'754': 'Joshua John Miller.txt'}
# {'755': 'Journey of Hope (film).txt'}
# {'756': 'Ju Dou.txt'}
# {'757': 'Judd Nelson.txt'}
# {'758': 'Judith Hoag.txt'}
# {'759': 'Julia Campbell.txt'}
# {'760': 'Julia Nickson.txt'}
# {'761': 'Julia Roberts.txt'}
# {'762': 'Julian Sands.txt'}
# {'763': 'Julianne Moore.txt'}
# {'764': 'Julie Benz.txt'}
# {'765': 'Julie Kavner.txt'}
# {'766': 'Juliet Stevenson.txt'}
# {'767': 'Jürgen Prochnow.txt'}
# {'768': 'Karel Reisz.txt'}
# {'769': 'Karey Kirkpatrick.txt'}
# {'770': 'Kate Capshaw.txt'}
# {'771': 'Kate Hodge.txt'}
# {'772': 'Kathy Baker.txt'}
# {'773': 'Kathy Bates.txt'}
# {'774': 'Kati Outinen.txt'}
# {'775': 'Kayla Blake.txt'}
# {'776': 'Keanu Reeves.txt'}
# {'777': 'Keene Curtis.txt'}
# {'778': 'Keisha Castle-Hughes.txt'}
# {'779': 'Keith David.txt'}
# {'780': 'Kelly Le Brock.txt'}
# {'781': 'Kelly Lynch.txt'}
# {'782': 'Ken Foree.txt'}
# {'783': 'Ken Friedman (screenwriter) (page does not exist).txt'}
# {'784': 'Ken Loach.txt'}
# {'785': 'Kendall Schmidt.txt'}
# {'786': 'Kevin Bacon.txt'}
# {'787': 'Kevin Clash.txt'}
# {'788': 'Kevin Connolly (actor).txt'}
# {'789': 'Kevin Costner.txt'}
# {'790': 'Kevin Kline.txt'}
# {'791': "Kevin O'Neill (comics).txt"}
# {'792': 'Kevin Pollak.txt'}
# {'793': 'Kevin Spacey.txt'}
# {'794': 'Kid Creole and the Coconuts.txt'}
# {'795': 'Kiefer Sutherland.txt'}
# {'796': "Kiki's Delivery Service.txt"}
# {'797': 'Kim Cattrall.txt'}
# {'798': 'Kim Myers.txt'}
# {'799': 'Kimberly Russell.txt'}
# {'800': 'Kindergarten Cop.txt'}
# {'801': 'King Hu.txt'}
# {'802': 'King of New York.txt'}
# {'803': 'Kirstie Alley.txt'}
# {'804': 'Klaudia Tiitsmaa.txt'}
# {'805': 'Klaus Maria Brandauer.txt'}
# {'806': 'Kristen Stewart.txt'}
# {'807': 'Kyle MacLachlan.txt'}
# {'808': 'Lacewood Productions.txt'}
# {'809': 'Laila Robins.txt'}
# {'810': 'Lala Sloatman.txt'}
# {'811': 'Lambada (1990 American film).txt'}
# {'812': 'Lane Smith.txt'}
# {'813': 'Lara Flynn Boyle.txt'}
# {'814': 'Larks on a String.txt'}
# {'815': 'Larry Cohen.txt'}
# {'816': 'Larry Drake.txt'}
# {'817': 'Larry Ferguson (screenwriter).txt'}
# {'818': 'Larry Gross.txt'}
# {'819': 'Last of the Finest.txt'}
# {'820': 'Laura Dern.txt'}
# {'821': 'Laura Harrier.txt'}
# {'822': 'Laura Harring.txt'}
# {'823': 'Laura San Giacomo.txt'}
# {'824': 'Lauren Bacall.txt'}
# {'825': 'Lauren Gale.txt'}
# {'826': 'Lauren Holly.txt'}
# {'827': 'Lauren Tom.txt'}
# {'828': 'Laurence Fishburne.txt'}
# {'829': 'Laurie Metcalf.txt'}
# {'830': 'Lawrence Kasdan.txt'}
# {'831': 'Lawrence Konner.txt'}
# {'832': 'Le Château de ma mère.txt'}
# {'833': 'Lea Thompson.txt'}
# {'834': 'Leatherface- The Texas Chainsaw Massacre III.txt'}
# {'835': 'Lena Olin.txt'}
# {'836': 'Leonard Maas, Jr. (page does not exist).txt'}
# {'837': 'Leonard Nimoy.txt'}
# {'838': 'Leonardo (Teenage Mutant Ninja Turtles).txt'}
# {'839': 'Leopold Stokowski.txt'}
# {'840': 'Les 1001 Nuits.txt'}
# {'841': 'Leslie Cheung.txt'}
# {'842': 'Leslie Hope.txt'}
# {'843': 'Leslie Jordan.txt'}
# {'844': 'Leslie Nielsen.txt'}
# {'845': 'Leticia Vasquez.txt'}
# {'846': 'Lewis Teague.txt'}
# {'847': 'Liam Hemsworth.txt'}
# {'848': 'Liam Neeson.txt'}
# {'849': 'Life Is Sweet (film).txt'}
# {'850': 'Linda Blair.txt'}
# {'851': 'Linda Hamilton.txt'}
# {'852': 'Linda Hunt.txt'}
# {'853': 'Linda Kozlowski.txt'}
# {'854': 'Linden Chiles.txt'}
# {'855': 'Lindsay Crouse.txt'}
# {'856': 'Lionheart (1990 film).txt'}
# {'857': 'Lisa (1990 film).txt'}
# {'858': 'Lisa Blount.txt'}
# {'859': 'Lisa Michelson.txt'}
# {'860': 'Lisa Zane.txt'}
# {'861': 'Live Action.txt'}
# {'862': 'Longtime Companion.txt'}
# {'863': 'Loni Anderson.txt'}
# {'864': "Look Who's Talking Too.txt"}
# {'865': 'Loose Cannons (1990 film).txt'}
# {'866': 'Lord of the Flies (1990 film).txt'}
# {'867': 'Lori Petty.txt'}
# {'868': 'Lorraine Bracco.txt'}
# {'869': 'Lorraine Nicholson.txt'}
# {'870': 'Loryn Locklin.txt'}
# {'871': 'Lou Diamond Phillips.txt'}
# {'872': 'Louis Gossett Jr..txt'}
# {'873': 'Louis Gossett, Jr..txt'}
# {'874': 'Louise Lasser.txt'}
# {'875': 'Love at Large.txt'}
# {'876': 'Luc Besson.txt'}
# {'877': 'Lucas Till.txt'}
# {'878': 'Luis Guzmán.txt'}
# {'879': 'Luis Mandoki.txt'}
# {'880': 'M. C. Gainey.txt'}
# {'881': 'M. Emmet Walsh.txt'}
# {'882': 'Mac McDonald.txt'}
# {'883': 'Macaulay Culkin.txt'}
# {'884': 'Mack the Knife (1989 film).txt'}
# {'885': 'Maddie Corman.txt'}
# {'886': 'Madeleine Stowe.txt'}
# {'887': 'Madeline Kahn.txt'}
# {'888': 'Madhouse (1990 film).txt'}
# {'889': 'Madonna (entertainer).txt'}
# {'890': 'Maggie Cheung.txt'}
# {'891': 'Mai Zetterling.txt'}
# {'892': 'Mako (actor).txt'}
# {'893': 'Mako Iwamatsu.txt'}
# {'894': 'Malcolm McDowell.txt'}
# {'895': 'Malcolm Mowbray.txt'}
# {'896': 'Mandy Patinkin.txt'}
# {'897': 'Marc Singer.txt'}
# {'898': 'Marcia Gay Harden.txt'}
# {'899': 'Margot Robbie.txt'}
# {'900': 'Maria de Medeiros.txt'}
# {'901': 'Mario Puzo.txt'}
# {'902': 'Marisa Berenson.txt'}
# {'903': 'María Conchita Alonso.txt'}
# {'904': 'Mark Hamill.txt'}
# {'905': 'Mark L. Lester.txt'}
# {'906': 'Mark Margolis.txt'}
# {'907': 'Mark Rosenthal (screenwriter).txt'}
# {'908': 'Marked for Death.txt'}
# {'909': 'Marlon Brando.txt'}
# {'910': 'Marsha Mason.txt'}
# {'911': 'Martha Plimpton.txt'}
# {'912': 'Martial arts film.txt'}
# {'913': 'Martians Go Home (film).txt'}
# {'914': 'Martin Kemp (actor).txt'}
# {'915': 'Martin Kemp (entertainer).txt'}
# {'916': 'Martin Mull.txt'}
# {'917': 'Martin Ritt.txt'}
# {'918': 'Martin Scorsese.txt'}
# {'919': 'Martin Sheen.txt'}
# {'920': 'Mary Alice.txt'}
# {'921': 'Mary McDonnell.txt'}
# {'922': 'Mary Steenburgen.txt'}
# {'923': 'Mary Stuart Masterson.txt'}
# {'924': 'Matt Craven.txt'}
# {'925': 'Matt Feemster (page does not exist).txt'}
# {'926': 'Matt Frewer.txt'}
# {'927': 'Matt Prokop.txt'}
# {'928': 'Matt Salinger.txt'}
# {'929': 'Matte painting.txt'}
# {'930': 'Matthew Broderick.txt'}
# {'931': 'Matthew Modine.txt'}
# {'932': 'Matthias Hues.txt'}
# {'933': 'Mavis Staples.txt'}
# {'934': 'Max von Sydow.txt'}
# {'935': 'Meg Ryan.txt'}
# {'936': 'Meg Tilly.txt'}
# {'937': 'Megan Follows.txt'}
# {'938': 'Megan Gallagher.txt'}
# {'939': 'Mel Blanc.txt'}
# {'940': 'Mel Gibson.txt'}
# {'941': 'Melanie Griffith.txt'}
# {'942': 'Melora Hardin.txt'}
# {'943': 'Memories of a River.txt'}
# {'944': 'Memphis Belle (film).txt'}
# {'945': "Men Don't Leave.txt"}
# {'946': 'Men at Work (1990 film).txt'}
# {'947': 'Mermaids (1990 film).txt'}
# {'948': 'Meryl Streep.txt'}
# {'949': 'Metro-Goldwyn-Mayer.txt'}
# {'950': 'Metropolitan (1990 film).txt'}
# {'951': 'Mia Farrow.txt'}
# {'952': 'Miami Blues (film).txt'}
# {'953': 'Miami Blues.txt'}
# {'954': 'Michael Biehn.txt'}
# {'955': 'Michael Blake (author).txt'}
# {'956': 'Michael Caine.txt'}
# {'957': 'Michael Caton-Jones.txt'}
# {'958': 'Michael Cimino.txt'}
# {'959': 'Michael Cristofer.txt'}
# {'960': 'Michael Dudikoff.txt'}
# {'961': 'Michael Gross (actor).txt'}
# {'962': 'Michael Hutchence.txt'}
# {'963': 'Michael Ironside.txt'}
# {'964': 'Michael J. Fox.txt'}
# {'965': 'Michael Keaton.txt'}
# {'966': 'Michael Learned.txt'}
# {'967': 'Michael McDowell (author).txt'}
# {'968': 'Michael Oliver (actor).txt'}
# {'969': 'Michael Richards.txt'}
# {'970': 'Michael Rooker.txt'}
# {'971': 'Michael Schoeffling.txt'}
# {'972': 'Michael Stephenson (actor).txt'}
# {'973': 'Michael Winslow.txt'}
# {'974': 'Michelangelo (Teenage Mutant Ninja Turtles).txt'}
# {'975': 'Michelle Pfeiffer.txt'}
# {'976': 'Mickey Rourke.txt'}
# {'977': 'Midnight Ride (film).txt'}
# {'978': 'Mieko Harada.txt'}
# {'979': 'Miguel Ferrer.txt'}
# {'980': 'Miguel Sandoval.txt'}
# {'981': 'Mike Binder.txt'}
# {'982': 'Mike Figgis.txt'}
# {'983': 'Mike Gabriel.txt'}
# {'984': 'Mike Leigh.txt'}
# {'985': 'Mike Nichols.txt'}
# {'986': "Miller's Crossing.txt"}
# {'987': 'Milou in May.txt'}
# {'988': 'Mimi Kennedy.txt'}
# {'989': 'Mimi Rogers.txt'}
# {'990': 'Miramax.txt'}
# {'991': 'Miriam Byrd-Nethery.txt'}
# {'992': 'Misery (film).txt'}
# {'993': 'Mitch Markowitz.txt'}
# {'994': 'Mitzi McCall.txt'}
# {'995': "Mo' Better Blues.txt"}
# {'996': 'Molly Ringwald.txt'}
# {'997': 'Monte Merrick (page does not exist).txt'}
# {'998': 'Morgan Creek Entertainment Group.txt'}
# {'999': 'Morgan Freeman.txt'}
# {'1000': 'Morris Day.txt'}
# {'1001': 'Motion capture.txt'}
# {'1002': 'Movie... In Your Face.txt'}
# {'1003': 'Mr. Destiny.txt'}
# {'1004': 'Mr. and Mrs. Bridge.txt'}
# {'1005': 'Musical film.txt'}
# {'1006': 'My Blue Heaven (1990 film).txt'}
# {'1007': "My Mother's Castle.txt"}
# {'1008': 'Mykelti Williamson.txt'}
# {'1009': 'Mystery film.txt'}
# {'1010': 'Nancy Allen (actress).txt'}
# {'1011': 'Nancy Travis.txt'}
# {'1012': 'Narrow Margin.txt'}
# {'1013': 'Nat Bernstein (page does not exist).txt'}
# {'1014': 'Nat Mauldin.txt'}
# {'1015': 'Natasha Richardson.txt'}
# {'1016': 'Navy SEALs (film).txt'}
# {'1017': 'Neal Israel.txt'}
# {'1018': 'Ned Beatty.txt'}
# {'1019': 'Neil Giuntoli.txt'}
# {'1020': 'New Line Cinema.txt'}
# {'1021': 'New World Pictures.txt'}
# {'1022': 'Nia Long.txt'}
# {'1023': 'Nicholas Eadie.txt'}
# {'1024': 'Nicholas Pileggi.txt'}
# {'1025': 'Nick Brimble.txt'}
# {'1026': 'Nick Cassavetes.txt'}
# {'1027': 'Nick Nolte.txt'}
# {'1028': 'Nicolas Cage.txt'}
# {'1029': 'Nicolas Roeg.txt'}
# {'1030': 'Nicole Gale Anderson.txt'}
# {'1031': 'Nicole Kidman.txt'}
# {'1032': 'Night of the Living Dead (1990 film).txt'}
# {'1033': 'Nightbreed.txt'}
# {'1034': 'Nikita (film).txt'}
# {'1035': 'Noble Willingham.txt'}
# {'1036': "Nobody's Perfect (1990 film).txt"}
# {'1037': 'Nora Ephron.txt'}
# {'1038': 'Norm Ferguson (animator).txt'}
# {'1039': 'Nuns on the Run.txt'}
# {'1040': 'Oliver Platt.txt'}
# {'1041': 'Olympia Dukakis.txt'}
# {'1042': 'Opportunity Knocks (film).txt'}
# {'1043': 'Orion Classics.txt'}
# {'1044': 'Orion Pictures.txt'}
# {'1045': 'Pacific Heights (film).txt'}
# {'1046': 'Pam Grier.txt'}
# {'1047': 'Pamela Reed.txt'}
# {'1048': 'Paramount Pictures.txt'}
# {'1049': 'Paris Chong (page does not exist).txt'}
# {'1050': 'Patric Zimmerman.txt'}
# {'1051': 'Patricia Tallman.txt'}
# {'1052': 'Patrick Bergin.txt'}
# {'1053': 'Patrick Dempsey.txt'}
# {'1054': 'Patrick Kilpatrick.txt'}
# {'1055': 'Patrick Read Johnson.txt'}
# {'1056': 'Patrick Swayze.txt'}
# {'1057': 'Patty Mullen.txt'}
# {'1058': 'Paul Bartel.txt'}
# {'1059': 'Paul Butler (actor) (page does not exist).txt'}
# {'1060': 'Paul Feig.txt'}
# {'1061': 'Paul Hogan.txt'}
# {'1062': 'Paul Koslo.txt'}
# {'1063': 'Paul Newman.txt'}
# {'1064': 'Paul Perri.txt'}
# {'1065': 'Paul Reiser.txt'}
# {'1066': 'Paul Schibli.txt'}
# {'1067': 'Paul Sorvino.txt'}
# {'1068': 'Paul Verhoeven.txt'}
# {'1069': 'Paul Winfield.txt'}
# {'1070': 'Pedro Almodóvar.txt'}
# {'1071': 'Penelope Ann Miller.txt'}
# {'1072': 'Penny Marshall.txt'}
# {'1073': 'Penny Singleton.txt'}
# {'1074': 'Peter Bogdanovich.txt'}
# {'1075': 'Peter Horton.txt'}
# {'1076': 'Peter Hyams.txt'}
# {'1077': 'Peter Markle.txt'}
# {'1078': 'Peter Medak.txt'}
# {'1079': 'Peter Viertel.txt'}
# {'1080': 'Peter Weller.txt'}
# {'1081': 'Phil Harris.txt'}
# {'1082': 'Phil Joanou.txt'}
# {'1083': 'Philip Kaufman.txt'}
# {'1084': 'Philip Ridley.txt'}
# {'1085': 'Philippe Noiret.txt'}
# {'1086': 'Phillip Noyce.txt'}
# {'1087': 'Phoebe Cates.txt'}
# {'1088': 'Piece of Cake (film) (page does not exist).txt'}
# {'1089': 'Polly Bergen.txt'}
# {'1090': 'Postcards from the Edge (film).txt'}
# {'1091': 'Predator 2.txt'}
# {'1092': 'Presumed Innocent (film).txt'}
# {'1093': 'Pretty Woman (film).txt'}
# {'1094': 'Pretty Woman.txt'}
# {'1095': 'Prince (musician).txt'}
# {'1096': 'Prince (singer).txt'}
# {'1097': 'Priscilla Presley.txt'}
# {'1098': 'Problem Child (film).txt'}
# {'1099': 'Pump Up the Volume (film).txt'}
# {'1100': 'Q&A (film).txt'}
# {'1101': 'Quick Change.txt'}
# {'1102': 'Quigley Down Under.txt'}
# {'1103': 'R. A. Mihailoff.txt'}
# {'1104': 'R. G. Armstrong.txt'}
# {'1105': 'Rachel Chagall.txt'}
# {'1106': 'Rachel Hurd-Wood.txt'}
# {'1107': 'Rachel Ticotin.txt'}
# {'1108': 'Rachel Ward.txt'}
# {'1109': 'Rae Dawn Chong.txt'}
# {'1110': 'Ralph Bellamy.txt'}
# {'1111': 'Randall -Tex- Cobb.txt'}
# {'1112': 'Randy Quaid.txt'}
# {'1113': 'Rank Film Distributors.txt'}
# {'1114': 'Raphael (Teenage Mutant Ninja Turtles).txt'}
# {'1115': 'Raúl Juliá.txt'}
# {'1116': 'Ray Barrett.txt'}
# {'1117': 'Ray Liotta.txt'}
# {'1118': 'Ray Walston.txt'}
# {'1119': 'Reba McEntire.txt'}
# {'1120': 'Red Buttons.txt'}
# {'1121': 'Reed Diamond.txt'}
# {'1122': 'Reginald Hudlin.txt'}
# {'1123': 'Reginald VelJohnson.txt'}
# {'1124': 'Rene Russo.txt'}
# {'1125': 'Renée Taylor.txt'}
# {'1126': 'Renny Harlin.txt'}
# {'1127': 'Repossessed (film).txt'}
# {'1128': 'Republic Pictures.txt'}
# {'1129': 'Revenge (1990 film).txt'}
# {'1130': 'Reversal of Fortune.txt'}
# {'1131': 'Richard Benjamin.txt'}
# {'1132': 'Richard Bradford (actor).txt'}
# {'1133': 'Richard Brooks.txt'}
# {'1134': 'Richard Christian Matheson.txt'}
# {'1135': 'Richard Correll.txt'}
# {'1136': 'Richard Dreyfuss.txt'}
# {'1137': 'Richard E. Grant.txt'}
# {'1138': 'Richard Farnsworth.txt'}
# {'1139': 'Richard Gere.txt'}
# {'1140': 'Richard Harris.txt'}
# {'1141': 'Richard Jaeckel.txt'}
# {'1142': 'Richard Kiley.txt'}
# {'1143': 'Richard Lynch (actor).txt'}
# {'1144': 'Richard Matheson.txt'}
# {'1145': 'Richard Roundtree.txt'}
# {'1146': 'Richard Rush (director).txt'}
# {'1147': 'Richard Stanley (film director).txt'}
# {'1148': 'Richard Tyson.txt'}
# {'1149': 'Rick Aviles.txt'}
# {'1150': 'Rick Moranis.txt'}
# {'1151': 'Rick Rossovich.txt'}
# {'1152': 'Ricki Lake.txt'}
# {'1153': 'Ricky Paull Goldin.txt'}
# {'1154': 'Rip Taylor.txt'}
# {'1155': 'River Phoenix.txt'}
# {'1156': 'Roadshow Entertainment.txt'}
# {'1157': 'Rob Lowe.txt'}
# {'1158': 'Rob Reiner.txt'}
# {'1159': 'Rob Schneider.txt'}
# {'1160': 'Robbie Coltrane.txt'}
# {'1161': 'Robbie Rist.txt'}
# {'1162': 'Robert -Bob- Martin.txt'}
# {'1163': 'Robert Beltran.txt'}
# {'1164': 'Robert Carlyle.txt'}
# {'1165': 'Robert Davi.txt'}
# {'1166': 'Robert De Niro.txt'}
# {'1167': 'Robert Downey, Jr..txt'}
# {'1168': 'Robert Downey, Sr..txt'}
# {'1169': 'Robert Duvall.txt'}
# {'1170': 'Robert Englund.txt'}
# {'1171': 'Robert Getchell.txt'}
# {'1172': 'Robert Ginty.txt'}
# {'1173': 'Robert Guillaume.txt'}
# {'1174': 'Robert Loggia.txt'}
# {'1175': 'Robert Patrick.txt'}
# {'1176': 'Robert Picardo.txt'}
# {'1177': 'Robert Prosky.txt'}
# {'1178': 'Robert Redford.txt'}
# {'1179': 'Robert Resnikoff (page does not exist).txt'}
# {'1180': 'Robert Schenkkan.txt'}
# {'1181': 'Robert Towne.txt'}
# {'1182': "Robert Z'Dar.txt"}
# {'1183': 'Robert Zemeckis.txt'}
# {'1184': 'Roberts Blossom.txt'}
# {'1185': 'Robin Harris.txt'}
# {'1186': 'Robin Weisman.txt'}
# {'1187': 'Robin Williams.txt'}
# {'1188': 'Robin Wright.txt'}
# {'1189': 'RoboCop 2.txt'}
# {'1190': 'Robot Jox.txt'}
# {'1191': "Rock 'n' Roll High School Forever.txt"}
# {'1192': 'Rockula.txt'}
# {'1193': 'Rocky V.txt'}
# {'1194': 'Roddy McDowall.txt'}
# {'1195': 'Rodney A. Grant.txt'}
# {'1196': 'Roger Corman.txt'}
# {'1197': 'Roger Donaldson.txt'}
# {'1198': 'Roger Engle (page does not exist).txt'}
# {'1199': 'Roger Rose.txt'}
# {'1200': 'Roger Spottiswoode.txt'}
# {'1201': 'Romance film.txt'}
# {'1202': 'Ron Silver.txt'}
# {'1203': 'Ron Underwood.txt'}
# {'1204': 'Ronald Shusett.txt'}
# {'1205': 'Ronny Cox.txt'}
# {'1206': 'Rose Kaufman.txt'}
# {'1207': 'Roseanne Barr.txt'}
# {'1208': 'Rosencrantz & Guildenstern Are Dead (film).txt'}
# {'1209': 'Rowan Atkinson.txt'}
# {'1210': 'Roy Scheider.txt'}
# {'1211': 'Roy Schneider.txt'}
# {'1212': 'Royal Dano.txt'}
# {'1213': 'Rubén Blades.txt'}
# {'1214': 'Russell Crowe.txt'}
# {'1215': 'Russi Taylor.txt'}
# {'1216': 'Rutger Hauer.txt'}
# {'1217': 'Ryuichi Sakamoto.txt'}
# {'1218': 'S. S. Wilson.txt'}
# {'1219': 'Saara Kadak.txt'}
# {'1220': 'Sage Stallone.txt'}
# {'1221': 'Sally Kirkland.txt'}
# {'1222': 'Salvatore Cascio.txt'}
# {'1223': 'Sam Anderson.txt'}
# {'1224': 'Sam Elliott.txt'}
# {'1225': 'Sam Neill.txt'}
# {'1226': 'Sam Raimi.txt'}
# {'1227': 'Samantha Mathis.txt'}
# {'1228': 'Samuel Hui.txt'}
# {'1229': 'Samuel L. Jackson.txt'}
# {'1230': 'Samurai cinema.txt'}
# {'1231': 'Sarah Bird.txt'}
# {'1232': 'Sasha Spielberg.txt'}
# {'1233': 'Saturday Night Live.txt'}
# {'1234': 'Saul Rubinek.txt'}
# {'1235': 'Science fiction film.txt'}
# {'1236': 'Scott Alexander and Larry Karaszewski.txt'}
# {'1237': 'Scott Bakula.txt'}
# {'1238': 'Scott Glenn.txt'}
# {'1239': 'Scott Paulin.txt'}
# {'1240': 'Scott Spiegel.txt'}
# {'1241': 'Scott Wilson (actor).txt'}
# {'1242': 'Sean Astin.txt'}
# {'1243': 'Sean Connery.txt'}
# {'1244': 'Sean Penn.txt'}
# {'1245': 'Sean Young.txt'}
# {'1246': 'Seth Green.txt'}
# {'1247': 'Seven Arts Pictures.txt'}
# {'1248': 'Shabba-Doo.txt'}
# {'1249': 'Shakma.txt'}
# {'1250': 'Shannon Farnon.txt'}
# {'1251': 'Shapiro-Glickenhaus Entertainment.txt'}
# {'1252': 'Sharla Cheung.txt'}
# {'1253': 'Sharon Stone.txt'}
# {'1254': 'Shawnee Smith.txt'}
# {'1255': 'Shelby Chong.txt'}
# {'1256': 'Shelley Long.txt'}
# {'1257': 'Shipwrecked (1990 film).txt'}
# {'1258': 'Shirley MacLaine.txt'}
# {'1259': 'Sho Kosugi.txt'}
# {'1260': 'Short Time.txt'}
# {'1261': 'Sibling Rivalry (film).txt'}
# {'1262': 'Sid Haig.txt'}
# {'1263': 'Side Out.txt'}
# {'1264': 'Sidney Lumet.txt'}
# {'1265': 'Sidney Poitier.txt'}
# {'1266': 'Silent Night, Deadly Night 4- Initiation.txt'}
# {'1267': 'Silent Scream (1990 film).txt'}
# {'1268': 'Simon Wincer.txt'}
# {'1269': 'Singapore Sling (1990 film).txt'}
# {'1270': 'Sissy Spacek.txt'}
# {'1271': 'Ski Patrol (1990 film).txt'}
# {'1272': 'Sofia Coppola.txt'}
# {'1273': 'Sooner or Later (Madonna song).txt'}
# {'1274': 'Soultaker (film).txt'}
# {'1275': 'Sônia Braga.txt'}
# {'1276': 'Spaced Invaders.txt'}
# {'1277': 'Spike Lee.txt'}
# {'1278': 'Sports film.txt'}
# {'1279': 'Stacey Travis.txt'}
# {'1280': 'Stacy Keach.txt'}
# {'1281': 'Stanley & Iris.txt'}
# {'1282': 'State of Grace (1990 film).txt'}
# {'1283': 'Stella (1990 film).txt'}
# {'1284': 'Stephen Collins (actor).txt'}
# {'1285': 'Stephen Elliott (actor).txt'}
# {'1286': 'Stephen Hopkins (director).txt'}
# {'1287': 'Stephen Macht.txt'}
# {'1288': 'Stephen Tobolowsky.txt'}
# {'1289': 'Stephen Volk.txt'}
# {'1290': 'Stephen Wallace.txt'}
# {'1291': 'Stephen Woolley.txt'}
# {'1292': 'Steve Barron.txt'}
# {'1293': 'Steve Guttenberg.txt'}
# {'1294': 'Steve MacManus.txt'}
# {'1295': 'Steve Martin.txt'}
# {'1296': 'Steven E. de Souza.txt'}
# {'1297': 'Steven Hill.txt'}
# {'1298': 'Steven Seagal.txt'}
# {'1299': 'Steven Spielberg.txt'}
# {'1300': 'Steven Zaillian.txt'}
# {'1301': 'Streamline Pictures.txt'}
# {'1302': 'Stuart Gordon.txt'}
# {'1303': 'Susan Sarandon.txt'}
# {'1304': 'Susan Tyrrell.txt'}
# {'1305': 'Suzy Amis.txt'}
# {'1306': 'Swoosie Kurtz.txt'}
# {'1307': 'Sydney Pollack.txt'}
# {'1308': 'Sylvester Stallone.txt'}
# {'1309': 'T. Hee.txt'}
# {'1310': 'T. K. Carter.txt'}
# {'1311': 'Takeshi Kitano.txt'}
# {'1312': 'Taking Care of Business (film).txt'}
# {'1313': 'Tales from the Darkside- The Movie.txt'}
# {'1314': 'Talia Shire.txt'}
# {'1315': 'Tamlyn Tomita.txt'}
# {'1316': 'Tate Donovan.txt'}
# {'1317': 'Tatie Danielle.txt'}
# {'1318': 'Taylor Nichols.txt'}
# {'1319': 'Ted Danson.txt'}
# {'1320': 'Ted Levine.txt'}
# {'1321': 'Ted Tally.txt'}
# {'1322': 'Teenage Mutant Ninja Turtles (1990 film).txt'}
# {'1323': 'Tekken (1990 film).txt'}
# {'1324': 'Teri Garr.txt'}
# {'1325': 'Terry McGovern (actor).txt'}
# {'1326': "Terry O'Quinn.txt"}
# {'1327': 'Tevin Campbell.txt'}
# {'1328': 'Texasville.txt'}
# {'1329': 'The Adventures of Ford Fairlane.txt'}
# {'1330': 'The Ages of Lulu.txt'}
# {'1331': 'The Ambulance.txt'}
# {'1332': 'The Big Man.txt'}
# {'1333': 'The Big Steal (1990 film).txt'}
# {'1334': 'The Bonfire of the Vanities (film).txt'}
# {'1335': 'The Comfort of Strangers (film).txt'}
# {'1336': 'The End of Innocence (film).txt'}
# {'1337': 'The Exorcist (film).txt'}
# {'1338': 'The Exorcist III.txt'}
# {'1339': 'The Field (film).txt'}
# {'1340': 'The First Power.txt'}
# {'1341': 'The Forbidden Dance.txt'}
# {'1342': 'The Fourth War.txt'}
# {'1343': 'The Freshman (1990 film).txt'}
# {'1344': 'The Godfather Part III.txt'}
# {'1345': 'The Grifters (film).txt'}
# {'1346': 'The Guardian (1990 film).txt'}
# {'1347': 'The Guyver.txt'}
# {'1348': "The Handmaid's Tale (film).txt"}
# {'1349': 'The Hot Spot.txt'}
# {'1350': 'The Hunt for Red October (film).txt'}
# {'1351': 'The Invisible Maniac.txt'}
# {'1352': 'The Jungle Book (1967 film).txt'}
# {'1353': 'The Krays (film).txt'}
# {'1354': 'The Lemon Sisters.txt'}
# {'1355': 'The Long Walk Home.txt'}
# {'1356': 'The Match Factory Girl.txt'}
# {'1357': 'The Nasty Girl.txt'}
# {'1358': 'The NeverEnding Story II- The Next Chapter.txt'}
# {'1359': 'The Nutcracker Prince.txt'}
# {'1360': 'The Reflecting Skin (film).txt'}
# {'1361': 'The Rescuers Down Under.txt'}
# {'1362': 'The Rookie (1990 film).txt'}
# {'1363': 'The Russia House (film).txt'}
# {'1364': 'The Samuel Goldwyn Company.txt'}
# {'1365': 'The Sheltering Sky (film).txt'}
# {'1366': 'The Sheltering Sky (soundtrack).txt'}
# {'1367': 'The Swordsman (1990 film).txt'}
# {'1368': 'The Two Jakes.txt'}
# {'1369': 'The Witches (1990 film).txt'}
# {'1370': 'Thomas Brodie-Sangster.txt'}
# {'1371': 'Thomas F. Wilson.txt'}
# {'1372': 'Thomas Wilson Brown.txt'}
# {'1373': 'Three Men and a Little Lady.txt'}
# {'1374': 'Thriller film.txt'}
# {'1375': 'Tibor Hernádi.txt'}
# {'1376': 'Tie Me Up! Tie Me Down!.txt'}
# {'1377': 'Tiffany (American singer).txt'}
# {'1378': 'Tilaï.txt'}
# {'1379': 'Tim Burton.txt'}
# {'1380': 'Tim Curry.txt'}
# {'1381': 'Tim Robbins.txt'}
# {'1382': 'Tim Roth.txt'}
# {'1383': 'Timeline of CGI in film and television.txt'}
# {'1384': 'Timothy Bottoms.txt'}
# {'1385': 'Timothy Hutton.txt'}
# {'1386': 'To Sleep with Anger.txt'}
# {'1387': 'Tod Davies.txt'}
# {'1388': 'Todd Graff.txt'}
# {'1389': 'Tom Bell (actor).txt'}
# {'1390': 'Tom Berenger.txt'}
# {'1391': 'Tom Cruise.txt'}
# {'1392': 'Tom Everett.txt'}
# {'1393': 'Tom Hanks.txt'}
# {'1394': 'Tom Logan (director).txt'}
# {'1395': 'Tom Noonan.txt'}
# {'1396': 'Tom Ropelewski.txt'}
# {'1397': 'Tom Savini.txt'}
# {'1398': 'Tom Selleck.txt'}
# {'1399': 'Tom Sizemore.txt'}
# {'1400': 'Tom Skerritt.txt'}
# {'1401': 'Tom Stoppard.txt'}
# {'1402': 'Tom Wright (actor).txt'}
# {'1403': 'Tomas Arana.txt'}
# {'1404': 'Tommy Chong.txt'}
# {'1405': 'Tommy Lee Jones.txt'}
# {'1406': 'Tommy Lee Wallace.txt'}
# {'1407': 'Tommy Morrison.txt'}
# {'1408': 'Toni Hudson.txt'}
# {'1409': 'Tony Bill.txt'}
# {'1410': 'Tony Goldwyn.txt'}
# {'1411': 'Tony Scott.txt'}
# {'1412': 'Tony Todd.txt'}
# {'1413': 'Tonya Lee Williams.txt'}
# {'1414': 'Too Much Sun.txt'}
# {'1415': 'Total Recall (1990 film).txt'}
# {'1416': 'Touchstone Pictures.txt'}
# {'1417': 'Tracey Ullman.txt'}
# {'1418': 'Traci Lind.txt'}
# {'1419': 'Traci Lords.txt'}
# {'1420': 'Tracy Griffith.txt'}
# {'1421': 'Treasure Island (1990 film).txt'}
# {'1422': 'Tremors (film).txt'}
# {'1423': 'TriStar Pictures.txt'}
# {'1424': 'Trini Alvarado.txt'}
# {'1425': 'Tristan Rogers.txt'}
# {'1426': 'Triumph Films.txt'}
# {'1427': 'Troll 2.txt'}
# {'1428': 'Truly, Madly, Deeply.txt'}
# {'1429': 'Tsilla Chelton.txt'}
# {'1430': 'Two Evil Eyes.txt'}
# {'1431': 'Uchū no hōsoku.txt'}
# {'1432': 'Ultra Q The Movie- Legend of the Stars.txt'}
# {'1433': 'Uma Thurman.txt'}
# {'1434': 'United Artists.txt'}
# {'1435': 'Universal Pictures.txt'}
# {'1436': 'Universal Studios.txt'}
# {'1437': 'Vanessa Bell Calloway.txt'}
# {'1438': 'Veronica Hamel.txt'}
# {'1439': 'Vestron Pictures.txt'}
# {'1440': 'Viggo Mortensen.txt'}
# {'1441': 'Vin Diesel.txt'}
# {'1442': 'Vincent & Theo.txt'}
# {'1443': 'Vincent Pérez.txt'}
# {'1444': 'Vincent Price.txt'}
# {'1445': 'Vincent Schiavelli.txt'}
# {'1446': 'Vincent and Me.txt'}
# {'1447': 'Virginia Madsen.txt'}
# {'1448': 'Volker Schlöndorff.txt'}
# {'1449': 'Walon Green.txt'}
# {'1450': 'Walt Disney Pictures.txt'}
# {'1451': 'Walter Hill (director).txt'}
# {'1452': 'Warner Bros..txt'}
# {'1453': 'Warren Beatty.txt'}
# {'1454': 'Wayne Alexander (actor).txt'}
# {'1455': 'Wayne Newton.txt'}
# {'1456': 'Wayne Robson.txt'}
# {'1457': 'Welcome Home, Roxy Carmichael.txt'}
# {'1458': 'Wesley Snipes.txt'}
# {'1459': 'Wesley Strick.txt'}
# {'1460': 'Western (genre).txt'}
# {'1461': 'Western film.txt'}
# {'1462': 'Where the Heart Is (1990 film).txt'}
# {'1463': 'Whit Stillman.txt'}
# {'1464': 'White Hunter Black Heart.txt'}
# {'1465': 'White Palace (film).txt'}
# {'1466': 'Whoopi Goldberg.txt'}
# {'1467': 'Wild Orchid (film).txt'}
# {'1468': 'Wild at Heart (film).txt'}
# {'1469': 'Wilfred Jackson.txt'}
# {'1470': 'Will Patton.txt'}
# {'1471': 'Willem Dafoe.txt'}
# {'1472': 'William Atherton.txt'}
# {'1473': 'William Baldwin.txt'}
# {'1474': 'William Butler (actor).txt'}
# {'1475': 'William Forsythe (actor).txt'}
# {'1476': 'William Friedkin.txt'}
# {'1477': 'William Goldman.txt'}
# {'1478': 'William Hanna.txt'}
# {'1479': 'William Harrison (author).txt'}
# {'1480': 'William Hickey (actor).txt'}
# {'1481': 'William Hurt.txt'}
# {'1482': 'William McNamara.txt'}
# {'1483': 'William Peter Blatty.txt'}
# {'1484': 'William Petersen.txt'}
# {'1485': 'William Sadler (actor).txt'}
# {'1486': 'Winona Ryder.txt'}
# {'1487': "Without You I'm Nothing (film).txt"}
# {'1488': 'Wolfgang Reitherman.txt'}
# {'1489': 'Wong Kar-wai.txt'}
# {'1490': 'Woody Allen.txt'}
# {'1491': 'Yang Fengliang.txt'}
# {'1492': 'Young Guns II.txt'}
# {'1493': 'Yves Robert.txt'}
# {'1494': 'Yvette Nipar.txt'}
# {'1495': 'Zach Galligan.txt'}
# {'1496': 'Zhang Yimou.txt'}

# %% [markdown]
# # test logging

# %%
import logging

t2 = logging.getLogger('test')


t = logging.getLogger('test')
f =logging.FileHandler('test.log')
t.addHandler(f)
t.setLevel(logging.ERROR)
t.error('testmessage1')

t2.error('testmessage2')

# %%
import csv
with open('did.txt', 'r') as f:
    data = csv.reader(f, delimiter='\t')
    rest_data = list(data)[211:]
print(rest_data)
# Out:
# [['211', 'Charles Beaumont.txt'], ['212', 'Charles Burnett (director).txt'], ['213', 'Charles Correll.txt'], ['214', 'Charles Durning.txt'], ['215', 'Charles Grodin.txt'], ['216', 'Charles Haid.txt'], ['217', 'Charles Robert Carner.txt'], ['218', 'Charles S. Haas.txt'], ['219', 'Charlie Korsmo.txt'], ['220', 'Charlie Sheen.txt'], ['221', 'Charlton Heston.txt'], ['222', 'Cheech Marin.txt'], ['223', 'Cher.txt'], ['224', 'Cheryl Ladd.txt'], ['225', 'Cheryl Pollak.txt'], ['226', "Child's Play 2.txt"], ['227', 'Childhood Days.txt'], ['228', 'China Cry.txt'], ['229', 'Chishū Ryū.txt'], ['230', 'Chloe Webb.txt'], ['231', 'Chris Columbus (filmmaker).txt'], ['232', 'Chris Eigeman.txt'], ['233', 'Chris Furrh.txt'], ['234', "Chris O'Donnell.txt"], ['235', 'Chris Phillips.txt'], ['236', 'Chris Rock.txt'], ['237', 'Christian Bale.txt'], ['238', 'Christian Clemenson.txt'], ['239', 'Christian Serratos.txt'], ['240', 'Christian Slater.txt'], ['241', 'Christina Ricci.txt'], ['242', 'Christine Ebersole.txt'], ['243', 'Christine Elise.txt'], ['244', 'Christine Lahti.txt'], ['245', 'Christopher -Kid- Reid.txt'], ['246', 'Christopher Atkins.txt'], ['247', 'Christopher Cazenove.txt'], ['248', 'Christopher Lee.txt'], ['249', 'Christopher Lloyd.txt'], ['250', 'Christopher Martin (entertainer).txt'], ['251', 'Christopher Massey.txt'], ['252', 'Christopher Plummer.txt'], ['253', 'Christopher Walken.txt'], ['254', 'Chuck Norris.txt'], ['255', 'Chuck Pfarrer.txt'], ['256', 'Chuck Williams (actor) (page does not exist).txt'], ['257', 'Cinema Paradiso.txt'], ['258', 'City Hunter- Bay City Wars.txt'], ['259', 'Class of 1999.txt'], ['260', 'Claudio Fragasso.txt'], ['261', 'Clayton Landey.txt'], ['262', 'Cleavant Derricks (actor).txt'], ['263', 'Clint Eastwood.txt'], ['264', 'Clive Barker.txt'], ['265', 'Cloris Leachman.txt'], ['266', 'Close-Up (1990 film).txt'], ['267', 'Coen brothers.txt'], ['268', 'Coins in the Fountain.txt'], ['269', 'Colin Friels.txt'], ['270', 'Columbia Pictures.txt'], ['271', 'Come See the Paradise.txt'], ['272', 'Comedy film.txt'], ['273', 'Computer graphics.txt'], ['274', 'Computer-generated imagery.txt'], ['275', 'Connie Young.txt'], ['276', 'Conrad Dunn.txt'], ['277', 'Corey Feldman.txt'], ['278', 'Corey Parker (actor).txt'], ['279', 'Coupe de Ville (film).txt'], ['280', 'Courage Mountain.txt'], ['281', 'Courtney Gains.txt'], ['282', 'Courtney Thorne-Smith.txt'], ['283', 'Craig R. Baxley.txt'], ['284', 'Craig Sheffer.txt'], ['285', 'Crash and Burn (1990 film).txt'], ['286', 'Crazy People.txt'], ['287', 'Crime fiction.txt'], ['288', 'Crispin Glover.txt'], ['289', 'Cry-Baby.txt'], ['290', 'Curtis Hanson.txt'], ['291', 'Cybill Shepherd.txt'], ['292', 'Cynda Williams.txt'], ['293', 'Cynthia Brimhall.txt'], ['294', 'Cynthia Gibb.txt'], ['295', 'Cyrano de Bergerac (1990 film).txt'], ['296', "Cyril O'Reilly.txt"], ['297', 'D. B. Sweeney.txt'], ['298', 'Dabney Coleman.txt'], ['299', 'Damon Wayans.txt'], ['300', 'Dan Aykroyd.txt'], ['301', 'Dan Greenburg.txt'], ['302', "Dan O'Bannon.txt"], ['303', "Dan O'Herlihy.txt"], ['304', 'Dana Carvey.txt'], ['305', 'Dances with Wolves.txt'], ['306', 'Daniel Stern (actor).txt'], ['307', 'Daniel Waters (screenwriter).txt'], ['308', 'Danny Aiello.txt'], ['309', 'Danny Glover.txt'], ['310', 'Danny Trejo.txt'], ['311', 'Danton Stone.txt'], ['312', 'Danuel Pipoly.txt'], ['313', 'Darkman.txt'], ['314', 'Darren E. Burrows.txt'], ['315', 'Daryl Hannah.txt'], ['316', 'Daveigh Chase.txt'], ['317', 'David -Shark- Fralick.txt'], ['318', 'David Ackroyd.txt'], ['319', 'David Andrews (actor).txt'], ['320', 'David Argue.txt'], ['321', 'David Arnott.txt'], ['322', 'David Carradine.txt'], ['323', 'David Caruso.txt'], ['324', 'David Cronenberg.txt'], ['325', 'David Frankel.txt'], ['326', 'David Green (director).txt'], ['327', 'David Hand (animator).txt'], ['328', 'David Hewlett.txt'], ['329', 'David J. Schow.txt'], ['330', 'David Johansen.txt'], ['331', 'David Koepp.txt'], ['332', 'David Loughery.txt'], ['333', 'David  ...
